# %%
import sys
from google.colab import drive
drive.mount('/content/drive')

import os
os.path.exists('/content/drive/MyDrive/Colab Notebooks/pytorch-CycleGAN-and-pix2pix/models/pytorch_ssim')
sys.path.append('/content/drive/MyDrive/Colab Notebooks/pytorch-CycleGAN-and-pix2pix/models/pytorch_ssim')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/pytorch-CycleGAN-and-pix2pix/models')

# %%
import pytorch_ssim
